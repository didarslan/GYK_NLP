# %%
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def preprocess_text(corpus):
    # Tokenization
    tokens = [word_tokenize(text.lower()) for text in corpus]  # lower() burada daha uygundur
    
    # Stopword Removal
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [
        [word for word in token if word.isalpha() and word not in stop_words]
        for token in tokens
    ]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [
        [lemmatizer.lemmatize(word) for word in token]
        for token in filtered_tokens
    ]
    
    # Join tokens back to string
    cleaned_corpus = [' '.join(token) for token in lemmatized_tokens]
    
    # TF-IDF Vectorization
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(cleaned_corpus)
    
    return X.toarray(), vectorizer.get_feature_names_out()

# %%
# Example usage
corpus = [
    "Artificial intelligence is transforming industries.",
    "Machine learning algorithms are improving rapidly.",
    "Natural language processing enables machines to understand human language.",
    "Deep learning is a powerful technique in AI.",
    "AI applications are becoming more prevalent in everyday life.",
    "Robotics and AI are closely linked.",
    "Data science is a key component of modern AI.",
    "AI ethics is an important field of study.",
    "Computer vision is a subset of AI.",
    "AI is revolutionizing healthcare and finance."
]

X_array, feature_names = preprocess_text(corpus)

# %%
df_tfidf = pd.DataFrame(X_array, columns=feature_names)

print("\nTF-IDF Feature Names:\n", feature_names)
print("\nTF-IDF Table:\n")
print(df_tfidf.round(2))
# Out:
# TF-IDF Feature Names:
#  ['ai' 'algorithm' 'application' 'artificial' 'becoming' 'closely'
#  'component' 'computer' 'data' 'deep' 'enables' 'ethic' 'everyday' 'field'
#  'finance' 'healthcare' 'human' 'important' 'improving' 'industry'
#  'intelligence' 'key' 'language' 'learning' 'life' 'linked' 'machine'
#  'modern' 'natural' 'powerful' 'prevalent' 'processing' 'rapidly'
#  'revolutionizing' 'robotics' 'science' 'study' 'subset' 'technique'
#  'transforming' 'understand' 'vision']
#
# TF-IDF Table:
#
#      ai  algorithm  application  artificial  becoming  closely  component  \
# 0  0.00       0.00         0.00         0.5      0.00     0.00       0.00
# 1  0.00       0.47         0.00         0.0      0.00     0.00       0.00
# 2  0.00       0.00         0.00         0.0      0.00     0.00       0.00
# 3  0.24       0.00         0.00         0.0      0.00     0.00       0.00
# 4  0.21       0.00         0.44         0.0      0.44     0.00       0.00
# ...
